# %%
using Plots
gr()  # use GR graphics backend
# Out:
# Plots.GRBackend()

# %%
σᵃ = 18.49
σᵐ = σᵃ / √12
μ = 0

num_months = 91 * 12 + 6
end_period = 2018
beginning_period = end_period - num_months / 12

srand(314159265)
virtual_reality = σᵐ * randn(num_months) + μ

println("From $(beginning_period) to $(end_period)")
println("Target SD = $σᵐ")
println("Simulated SD   = $(std(virtual_reality))")
println("Simulated Mean = $(mean(virtual_reality))")
# Out:
# From 1926.5 to 2018
# Target SD = 5.33760323865809
# Simulated SD   = 5.444603790026529
# Simulated Mean = -0.13583220670726065

# %%
function gen_sample_sd(series, lookbacks)
    sqrt12 = 12^0.5
    sample_sd = []
    for lb in lookbacks
        sds = []    #Save Lookback-length SD's in Sds
        for x in 1:length(series)-lb
            std_dev = std(series[x:x+lb])
            push!(sds, std_dev * sqrt12)
        end
        push!(sample_sd, sds)   #Add a row to SampleSd
    end
    return(sample_sd)
end
# Out:
# gen_sample_sd (generic function with 1 method)

# %%
dates = linspace(beginning_period, end_period, num_months)
# Out:
# 1926.5:0.08340929808568824:2018.0

# %%
lookbacks = [12, 36, 60]
sample_sd = gen_sample_sd(virtual_reality, lookbacks)
# Out:
# 3-element Array{Any,1}:
#  Any[26.0082, 26.3085, 26.3096, 24.2027, 18.8003, 18.3969, 16.6958, 16.3034, 16.4692, 16.5331  …  17.832, 17.0163, 18.5527, 16.6044, 15.6755, 20.5781, 19.38, 16.9273, 17.2207, 17.556]
#  Any[21.4906, 21.38, 21.3537, 21.3743, 19.2078, 18.6972, 18.098, 18.8496, 18.3989, 18.7735  …  18.5844, 18.4004, 18.1903, 18.0874, 17.974, 19.1159, 18.8792, 18.8612, 19.0313, 19.1293]
#  Any[20.7938, 20.8441, 20.7131, 20.0065, 18.5832, 18.2818, 17.9576, 17.9854, 17.6732, 17.6794  …  19.5724, 19.5649, 19.5427, 19.3823, 19.1939, 19.8287, 19.9346, 19.2713, 19.3579, 19.3472]

# %%
plot()  # start a new plot
for i in 1:length(lookbacks)
    start_date = lookbacks[i] + 1
    plot!(
        dates[start_date:end], sample_sd[i], 
        linewidth = 2, 
        label = "$(lookbacks[i]) month")
end
plot!(xlabel = "Date", ylabel = "Sample SDs")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip3300">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip3300)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip3301">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip3300)" points="
# 44.6753,360.065 580.315,360.065 580.315,11.811 44.6753,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip3302">
#     <rect x="44" y="11" width="537" height="349"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip3302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   118.654,360.065 118.654,11.811
#   "/>
# <polyline clip-path="url(#clip3302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   237.029,360.065 237.029,11.811
#   "/>
# <polyline clip-path="url(#clip3302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   355.403,360.065 355.403,11.811
#   "/>
# <polyline clip-path="url(#clip3302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   473.778,360.065 473.778,11.811
#   "/>
# <polyline clip-path="url(#clip3302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   44.6753,346.5 580.315,346.5
#   "/>
# <polyline clip-path="url(#clip3302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   44.6753,267.951 580.315,267.951
#   "/>
# <polyline clip-path="url(#clip3302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   44.6753,189.401 580.315,189.401
#   "/>
# <polyline clip-path="url(#clip3302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   44.6753,110.852 580.315,110.852
#   "/>
# <polyline clip-path="url(#clip3302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   44.6753,32.3025 580.315,32.3025
#   "/>
# <polyline clip-path="url(#clip3300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   44.6753,360.065 580.315,360.065
#   "/>
# <polyline clip-path="url(#clip3300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   44.6753,360.065 44.6753,11.811
#   "/>
# <polyline clip-path="url(#clip3300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   118.654,360.065 118.654,354.842
#   "/>
# <polyline clip-path="url(#clip3300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   237.029,360.065 237.029,354.842
#   "/>
# <polyline clip-path="url(#clip3300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   355.403,360.065 355.403,354.842
#   "/>
# <polyline clip-path="url(#clip3300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   473.778,360.065 473.778,354.842
#   "/>
# <polyline clip-path="url(#clip3300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   44.6753,346.5 52.7099,346.5
#   "/>
# <polyline clip-path="url(#clip3300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   44.6753,267.951 52.7099,267.951
#   "/>
# <polyline clip-path="url(#clip3300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   44.6753,189.401 52.7099,189.401
#   "/>
# <polyline clip-path="url(#clip3300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   44.6753,110.852 52.7099,110.852
#   "/>
# <polyline clip-path="url(#clip3300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   44.6753,32.3025 52.7099,32.3025
#   "/>
# <g clip-path="url(#clip3300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 118.654, 373.865)" x="118.654" y="373.865">1940</text>
# </g>
# <g clip-path="url(#clip3300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 237.029, 373.865)" x="237.029" y="373.865">1960</text>
# </g>
# <g clip-path="url(#clip3300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 355.403, 373.865)" x="355.403" y="373.865">1980</text>
# </g>
# <g clip-path="url(#clip3300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 473.778, 373.865)" x="473.778" y="373.865">2000</text>
# </g>
# <g clip-path="url(#clip3300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 38.6753, 351)" x="38.6753" y="351">10</text>
# </g>
# <g clip-path="url(#clip3300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 38.6753, 272.451)" x="38.6753" y="272.451">15</text>
# </g>
# <g clip-path="url(#clip3300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 38.6753, 193.901)" x="38.6753" y="193.901">20</text>
# </g>
# <g clip-path="url(#clip3300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 38.6753, 115.352)" x="38.6753" y="115.352">25</text>
# </g>
# <g clip-path="url(#clip3300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 38.6753, 36.8025)" x="38.6753" y="36.8025">30</text>
# </g>
# <g clip-path="url(#clip3300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(0, 312.495, 397.6)" x="312.495" y="397.6">Date</text>
# </g>
# <g clip-path="url(#clip3300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(-90, 14.4, 185.938)" x="14.4" y="185.938">Sample SDs</text>
# </g>
# <polyline clip-path="url(#clip3302)" style="stroke:#009af9; stroke-width:2; stroke-opacity:1; fill:none" points="
#   44.6753,95.0127 45.169,90.2951 45.6627,90.2776 46.1564,123.378 46.65,208.248 47.1437,214.586 47.6374,241.31 48.1311,247.475 48.6247,244.87 49.1184,243.866
#   49.6121,238.003 50.1058,242.866 50.5994,232.742 51.0931,230.495 51.5868,246.769 52.0805,230.588 52.5742,238.904 53.0678,236.354 53.5615,237.888 54.0552,236.617
#   54.5489,234.399 55.0425,257.418 55.5362,222.451 56.0299,232.979 56.5236,195.233 57.0172,201.996 57.5109,208.592 58.0046,143.401 58.4983,165.797 58.992,164.376
#   59.4856,167.707 59.9793,145.177 60.473,147.744 60.9667,137.811 61.4603,116.324 61.954,135.161 62.4477,133.077 62.9414,148.2 63.4351,160.337 63.9287,175.043
#   64.4224,161.433 64.9161,162.163 65.4098,157.973 65.9034,158.772 66.3971,203.792 66.8908,196.747 67.3845,209.057 67.8781,222.96 68.3718,254.647 68.8655,259.636
#   69.3592,263.546 69.8529,267.339 70.3465,269.778 70.8402,327.353 71.3339,314.684 71.8276,298.598 72.3212,297.639 72.8149,298.624 73.3086,304.879 73.8023,267.52
#   74.2959,219.856 74.7896,223.591 75.2833,229.618 75.777,229.463 76.2707,233.449 76.7643,227.639 77.258,215.487 77.7517,190.13 78.2454,202.228 78.739,203.133
#   79.2327,202.328 79.7264,196.006 80.2201,220.84 80.7137,307.865 81.2074,289.584 81.7011,250.037 82.1948,246.37 82.6885,255.667 83.1821,270.225 83.6758,258.429
#   84.1695,267.718 84.6632,265.072 85.1568,263.284 85.6505,263.343 86.1442,
